# %% [markdown]
# # Data Analyst Associate Practical Exam Submission
#
# **You can use any tool that you want to do your analysis and create visualizations. Use this template to write up your summary for submission.**
#
# You can use any markdown formatting you wish. If you are not familiar with Markdown, read the [Markdown Guide](https://s3.amazonaws.com/talent-assets.datacamp.com/Markdown+Guide.pdf) before you start.

# %% [markdown]
# The pet supplies dataset comprises of 1500 rows and 8 columns. The columns include Product ID, Sales, Category, Size, Price, Rating, and Repeat Purchase. The dataset is relatively clean, with no missing values, except for the Rating column. However, some columns may contain incorrect data. The dataset comprises of three data types: integer, object, and float, and some columns may need to be casted to a different data type for further analysis.

# %% [markdown]
# ## DATA VALIDATION

# %% [markdown]
# Based on the resources given, data se was cleaned to adhere to the standards. Some techniques used involved replacing values, casting data type,and fixing incorrect data entries to ensure the datset matched what was expected. Here are the result
# - The **rating** columns contains values between 1-10. 150 null values were discovered. To remedy this, the missing values were replaced with 0 as dictated by the documentation.
# - The **product_id** column had 1500 values with no duplicates,missing value and had the proper data type.
# - The **category** column contained 7 categories with one being '-' instead of 6 categories containing equipment,food,toys,medicine,housing, and accessory.25 Values that were given _'-'_ were classfied as missing values and was replaced with unknown.
# - The **animal** category checked out the data validation list with four categories:Cat,fish,dog, and bird.
# - The **size** column contained 9 categories which did not match with the expected 3 categories. Further analysis showed that this was due to inconsistencies in size name. some were written in either  camel case,lower or upper case.To fix this, they were all converted to lower case leaving the column with 3 values(small,medium and large) as expected.
# - The **price** column had values of different data type. The minimum value of the column was checked to ensure there wereno negative values.The column had 150 field with string value _"unlisted"_.	This was replaced with the median price of the dataset.	To resolve the data type issue, the column was converted to float64 and then rounded to two decimal places.
# - The **sales** column checked out with validation. Only changes made was rounding it to two decimal places.
# - The **repeat_purchase** column had no null values and was categorised into 1 and 0 as expected.

# %% [markdown]
# ## REPEAT PURCHASES ACROSS CATEGORIES

# %% [markdown]
# - ## How often do repeat purchases happen?
# - ## What is the proportion of repeat purchase observations in each category of the variable?

# %% [markdown]
# ![count_repeat_purchase](count_repeat_purchase.png)

# %% [markdown]
# The data analysis of the store's purchases shows a significant trend of repeat customers, with **906**out of **1500** purchases being repeat purchases.This represents **60%** of the total purchases. Among the different product categories, equipment has the highest rate of purchases, accounting for **24.4%** of total purchases. Furthermore, equipment is also the most popular category, with **370** purchases in total. An in-depth analysis of the ratio of repeat purchases to total purchases shows that customers who purchase **housing** products have the highest rate of repeat purchases at **66.9%** of total housing purchases, followed by customers who purchase **medicine** at **64.5%** of total medicine purchase. **Equipment** comes in third with a repeat purchase rate of **59.7%** of total equipment purchases. These findings suggest that customers have a strong tendency to return to the store for repeat purchases for medicine, housing and equipmentts while accessories has the lowest purchases as well as repeat purchases.

# %% [markdown]
# ![Purchase_per_category](Purchase_per_category.png)

# %% [markdown]
# ## How are all sales distributed?

# %% [markdown]
# - The **equipment** category brings in the biggest sales followed by Toys and Food.Equipment makes up **23%** of total sales
# - Products with ratings between 3 to 6 brings in the highest number of sales with **6** making **20%** of total sales. It can be said that the rating of a product does not necessarily increase its sale
# - Cat can also be seen to bring in **38%** sales which is the most with **37%** of the purchases being repeated.
# - Size **small** brings in **50%** of sales and makes up **49%** of repeated_purchases.

# %% [markdown]
# ![var_vs_sales correct](var_vs_sales%20correct.png)

# %% [markdown]
# The  histogram of the sales data displays a bell-shaped curve, it indicates that the data is symmetric and the majority of sales  are concentrated around the mean which is # 996.

# %% [markdown]
# ![sales histogram](sales%20histogram.png)

# %% [markdown]
# ## What impact does repeat purchases have on sales?

# %% [markdown]
# The interquartile range of the repeat_purchase is lower than purchases not repeated.It's highly likely that this is as a result of repeat_purchases being larger. The maximum sales, excluding outliers,is around 1600.75% of repeat_purchases are below 1250,while 50% are between 750 and 1250. We can say that repeat purchases are more when sales is between 250 and 1750

# %% [markdown]
# ![repeat vs sales](repeat%20vs%20sales.png)
# _

# %% [markdown]
# ## Deductions

# %% [markdown]
# The analysis of the data suggests that repeat purchases constitute a substantial proportion of total purchases.
# - While medicine and housing have the highest number of repeat purchases, equipment has the most total purchases, and also has the third highest number of repeat purchases.
# - Additionally, cat is the animal with the highest number of sales, and have the highest rate of repeat purchases. The same can be said for the size small.
# - Furthermore, it can be seen that equipment products generate substantial sales due to their high purchase frequency. Additionally, toys, which are the third most frequently purchased category, also tend to generate more sales. On the other hand, smaller products such as housing and medicine have a relatively higher proportion of repeat purchases.
# - Looking at ratings, products rated 6 bring in the highest sales yet,those rated 4  have the highest repeated purchase by a small margin.
# - It can be inferred from the data that repeat purchases do not have a significant impact on sales, and the variables with the highest number of sales do not necessarily mean they have the highest number of repeat purchases.
# - Furthermore, it implies that other factors such as product size, animal type, and product category are more influential in determining sales.

# %% [markdown]
# ## ✅ When you have finished...
# -  Publish your Workspace using the option on the left
# -  Check the published version of your report:
# 	-  Can you see everything you want us to grade?
#     -  Are all the graphics visible?
# -  Review the grading rubric. Have you included everything that will be graded?
# -  Head back to the [Certification Dashboard](https://app.datacamp.com/certification) to submit your practical exam
